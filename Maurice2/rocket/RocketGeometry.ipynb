# %%
import sys
import os

# add Folder1 to path
sys.path.append(os.path.abspath("../Control"))


import datetime
import numpy as np
from scipy import linalg

from rocketpy import Environment, SolidMotor, Rocket, Flight
from rocketpy.control.controller import _Controller
import matplotlib.pyplot as plt
import pandas as pd

import numpy as np

from rocketpy.plots.aero_surface_plots import _TrapezoidalFinsPlots
from rocketpy.prints.aero_surface_prints import _TrapezoidalFinsPrints

from rocketpy.rocket.aero_surface.fins.trapezoidal_fins import TrapezoidalFins


class ourFins(TrapezoidalFins):
    def __init__(
        self,
        n,
        root_chord,
        tip_chord,
        span,
        rocket_radius,
        cant_angle=0,  # degrees
        sweep_length=None,
        sweep_angle=None,
        airfoil=None,
        name="Fins",
    ):
        super().__init__(
            n,
            root_chord,
            tip_chord,
            span,
            rocket_radius,
            cant_angle,
            sweep_length,
            sweep_angle,
            airfoil,
            name,
        )

        self.aileronAngles = np.array([0,0,0,0])

# %%
from rocketpy import Environment, SolidMotor, Rocket, Flight
from rocketpy.rocket.aero_surface.fins.trapezoidal_fins import TrapezoidalFins
import numpy as np
import datetime

class ourFins(TrapezoidalFins):
    def __init__(
        self,
        n,
        root_chord,
        tip_chord,
        span,
        rocket_radius,
        cant_angle=0,  # degrees
        sweep_length=None,
        sweep_angle=None,
        airfoil=None,
        name="Fins",
    ):
        super().__init__(
            n,
            root_chord,
            tip_chord,
            span,
            rocket_radius,
            cant_angle,
            sweep_length,
            sweep_angle,
            airfoil,
            name,
        )

        self.aileronAngles = np.array([0,0,0,0])

maurice2 = Rocket(
    radius=7.87/2/100,
    mass=2328/1000,
    inertia=(0.287, 0.287, 0.0035),
    power_off_drag=0.6175,
    power_on_drag=0.633,
    # power_off_drag=str("/Users/dsong/Library/CloudStorage/OneDrive-UniversityofIllinois-Urbana/Club Stuff/LRI/FV-Controls/Maurice2/data/drag_no_thrust.csv"),
    # power_on_drag=str("/Users/dsong/Library/CloudStorage/OneDrive-UniversityofIllinois-Urbana/Club Stuff/LRI/FV-Controls/Maurice2/data/drag_with_thrust.csv"),
    center_of_mass_without_motor=59.7/100,
    coordinate_system_orientation="nose_to_tail",
)

## Define solid motor ##
# motor = SolidMotor(
#     thrust_source= str(THRUST_FILE),
#     dry_mass=(0.616 - 0.355),  # kg
#     burn_time=1.971,  # Corrected burn time
#     dry_inertia=(0.00055, 0.00055, 0.00011),  # kg·m² (approximated)
#     nozzle_radius= (10 / 1000), 
#     grain_number=1,
#     grain_density=16929, 
#     grain_outer_radius= 0.038/2,  
#     grain_initial_inner_radius= 0.037/ 2,
#     grain_initial_height= 0.356,  
#     grain_separation=0.01,  
#     grains_center_of_mass_position=-0.07,  # Estimated
#     center_of_dry_mass_position=0.05,  # Estimated
#     nozzle_position=-0.28,
#     throat_radius= 3.5 / 1000,  
#     coordinate_system_orientation="nozzle_to_combustion_chamber",
# )

motor = SolidMotor(
    thrust_source=str("/Users/dsong/Library/CloudStorage/OneDrive-UniversityofIllinois-Urbana/Club Stuff/LRI/FV-Controls/Maurice2/data/AeroTech_HP-I280DM.eng"),  # Or use a CSV thrust file
    dry_mass=(0.616 - 0.355),  # kg
    burn_time=1.971,  # Corrected burn time
    dry_inertia=(0.00055, 0.00055, 0.00011),  # kg·m² (approximated)
    # Fixed Geometries to make propellant mass = 0.355 kg
    nozzle_radius= (10 / 1000), 
    grain_number=5,
    grain_density=1800, # Fixed grain density 18 --> 1800 kg·m^3
    grain_outer_radius= 16 / 1000,  
    grain_initial_inner_radius= 6 / 1000,  
    grain_initial_height= 57 / 1000,  
    grain_separation=0.01,  
    grains_center_of_mass_position=-0.1044,  # Estimated
    center_of_dry_mass_position=-0.122,  # Estimated
    nozzle_position=-0.3,
    throat_radius= 3.5 / 1000,  
    coordinate_system_orientation="nozzle_to_combustion_chamber",
)

maurice2.add_motor(motor, position=88.2/100)


nose_cone = maurice2.add_nose(
    length=19/100, kind="Von Karman", position=0
)

# Boat tail
tail = maurice2.add_tail(
    top_radius=7.87/2/100, bottom_radius=5.72/2/100, length=3.81/100, position=(117-3.81)/100
)

# Created in fin.py, inherited from RocketPy TrapezoidalFins class
fins = ourFins(
    n=4,
    root_chord=18/100,
    tip_chord=5.97/100,
    span=8.76/100,
    rocket_radius=7.87/2/100,
    cant_angle=0.01,  # degrees
    sweep_length=14.3/100,
)

maurice2.add_surfaces(fins, (92.3)/100)

env = Environment(latitude=41.92298772007185, longitude=-88.06013490408121, elevation=243.43)
tomorrow = datetime.date.today() + datetime.timedelta(days=1)
env.set_date((tomorrow.year, tomorrow.month, tomorrow.day, 12))  
env.set_atmospheric_model(type="Forecast", file="GFS")
maurice2.draw()

test_flight = Flight(
    rocket=maurice2, environment=env, rail_length=5.2, inclination=85, heading=0
    )

test_flight.info()

test_flight.export_data(
            "compare_rocketpy.csv",
            "w1",
            "w2",
            "w3",
            "alpha1",
            "alpha2",
            "alpha3",
            "vx",
            "vy",
            "vz",
            "x",
            "y",
            "z",
            "e0",
            "e1",
            "e2",
            "e3",
        )
# Out:
# Initial Conditions
#
# Initial time: 0.000 s
# Position - x: 0.00 m | y: 0.00 m | z: 224.00 m
# Velocity - Vx: 0.00 m/s | Vy: 0.00 m/s | Vz: 0.00 m/s
# Attitude (quaternions) - e0: 0.999 | e1: -0.044 | e2: 0.000 | e3: 0.000
# Euler Angles - Spin φ : 0.00° | Nutation θ: -5.00° | Precession ψ: 0.00°
# Angular Velocity - ω1: 0.00 rad/s | ω2: 0.00 rad/s | ω3: 0.00 rad/s
# Initial Stability Margin: 2.137 c
#
#
# Surface Wind Conditions
#
# Frontal Surface Wind Speed: 2.19 m/s
# Lateral Surface Wind Speed: -0.91 m/s
#
#
# Launch Rail
#
# Launch Rail Length: 5.2 m
# Launch Rail Inclination: 85.00°
# Launch Rail Heading: 0.00°
#
#
# Rail Departure State
#
# Rail Departure Time: 0.333 s
# Rail Departure Velocity: 32.299 m/s
# Rail Departure Stability Margin: 2.229 c
# Rail Departure Angle of Attack: 4.353°
# Rail Departure Thrust-Weight Ratio: 11.060
# Rail Departure Reynolds Number: 1.778e+05
#
#
# Burn out State
#
# Burn out time: 1.971 s
# Altitude at burn out: 408.121 m (ASL) | 184.123 m (AGL)
# Rocket speed at burn out: 166.481 m/s
# Freestream velocity at burn out: 166.405 m/s
# Mach Number at burn out: 0.494
# Kinetic energy at burn out: 3.588e+04 J
#
#
# Apogee State
#
# Apogee Time: 13.597 s
# Apogee Altitude: 1196.495 m (ASL) | 972.497 m (AGL)
# Apogee Freestream Speed: 6.617 m/s
# Apogee X position: -23.034 m
# Apogee Y position: 91.996 m
# Apogee latitude: 41.9238154°
# Apogee longitude: -88.0604134°
#
#
# Parachute Events
#
# No Parachute Events Were Triggered.
#
#
# Impact Conditions
#
# Time of impact: 29.432 s
# X impact: -3.998 m
# Y impact: 178.688 m
# Altitude impact: 223.998 m (ASL) | 0.000 m (AGL)
# Latitude: 41.9245953°
# Longitude: -88.0601832°
# Vertical velocity at impact: -102.264 m/s
# Number of parachutes triggered until impact: 0
#
#
# Stability Margin
#
# Initial Stability Margin: 2.137 c at 0.00 s
# Out of Rail Stability Margin: 2.229 c at 0.33 s
# Maximum Stability Margin: 2.743 c at 1.97 s
# Minimum Stability Margin: 2.137 c at 0.00 s
#
#
# Maximum Values
#
# Maximum Speed: 167.507 m/s at 1.88 s
# Maximum Mach Number: 0.497 Mach at 1.88 s
# Maximum Reynolds Number: 9.041e+05 at 1.87 s
# Maximum Dynamic Pressure: 1.691e+04 Pa at 1.87 s
# Maximum Acceleration During Motor Burn: 106.253 m/s² at 0.02 s
# Maximum Gs During Motor Burn: 10.835 g at 0.02 s
# Maximum Acceleration After Motor Burn: 0.685 m/s² at 0.00 s
# Maximum Gs After Motor Burn: 0.070 Gs at 0.00 s
# Maximum Stability Margin: 2.743 c at 1.97 s
#
#
# Numerical Integration Settings
#
# Maximum Allowed Flight Time: 600.00 s
# Maximum Allowed Time Step: inf s
# Minimum Allowed Time Step: 0.00e+00 s
# Relative Error Tolerance: 1e-06
# Absolute Error Tolerance: [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 1e-06, 1e-06, 1e-06, 1e-06, 0.001, 0.001, 0.001]
# Allow Event Overshoot: True
# Terminate Simulation on Apogee: False
# Number of Time Steps Used: 840
# Number of Derivative Functions Evaluation: 2034
# Average Function Evaluations per Time Step: 2.421

# %%
import pandas as pd
import matplotlib.pyplot as plt
or_data = pd.read_csv("compare_openrocket.csv")
rp_data = pd.read_csv("compare_rocketpy.csv")

rp_mask = rp_data["# Time (s)"] <= 13.571
or_mask = or_data["# Time (s)"] <= 13.571
rp_data = rp_data[rp_mask] - rp_data[rp_mask].iloc[0]
or_data = or_data[or_mask]

def compare_or():
    """Plot comparison between RocketPy and OpenRocket simulation data for altitude and velocity over time.
    """
    plt.figure(figsize=(10,6))
    plt.plot(rp_data["# Time (s)"], rp_data[" Z (m)"], label="RocketPy Altitude", color='blue')
    plt.plot(or_data["# Time (s)"], or_data["Altitude (m)"], label="OpenRocket Altitude", color='orange', linestyle='--')
    plt.xlabel("Time (s)")
    plt.ylabel("Altitude (m)")
    plt.title("Altitude vs Time Comparison")
    plt.legend()
    plt.grid()
    plt.show()

    plt.figure(figsize=(10,6))
    plt.plot(rp_data["# Time (s)"], rp_data[" ω3 (rad/s)"], label="RocketPy Roll Rate", color='blue')
    # plt.plot(or_data["# Time (s)"], np.deg2rad(or_data["Roll rate (°/s)"]), label="OpenRocket Roll Rate", color='orange', linestyle='--')
    plt.xlabel("Time (s)")
    plt.ylabel("Roll Rate (°/s)")
    plt.title("Roll Rate vs Time Comparison")
    plt.legend()
    plt.grid()
    plt.show()

compare_or()
